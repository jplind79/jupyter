# %% [markdown]
# # Approximate PI through Monte Carlo calculations

# %% [markdown]
# ## These are the relevant equations:

# %% [markdown]
# - square area: $s = (2 r)^2$
# - circle area: $c = \pi r^2$
# - $c/s = (\pi r^2) / (4 r^2) = \pi / 4$
# - $\pi = 4 * c/s$

# %% [markdown]
# ### Visual example

# %% [markdown]
# ![Darts](https://coderefinery.github.io/jupyter/img/darts.svg)

# %% [markdown]
# ### Import relevant modules

# %%
import random
import matplotlib.pyplot as plt

# %%
num_points = 10000

# %% [markdown]
# ### Throwing darts

# %%
points = []
hits = 0
for _ in range(num_points):
 x, y = random.random(), random.random()
 if x*x + y*y < 1.0:
     hits += 1
     points.append((x, y, "red"))
 else:
     points.append((x, y, "blue"))

# %% [markdown]
# ### Plot results

# %%
# %matplotlib inline
x, y, colors = zip(*points)
fig, ax = plt.subplots()
fig.set_size_inches(6.0, 6.0)
ax.scatter(x, y, c=colors)

# %% [markdown]
# ### Value of Pi:

# %%
fraction = hits / num_points
4 * fraction
# Out:
# 3.1232
